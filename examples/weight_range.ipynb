# %%
# !pip install climbing_cams

# %%
import climbing_cams as cams
import matplotlib.pyplot as plt

# %%
c = cams.db.select(name='C4')
u = cams.db.select(name='UL')
t = cams.db.select(brand='Totem')
w = cams.db.select(name='Friend')

# %%
fig, ax = cams.plots.weight_range(c)
# fig, ax = cams.plots.weight_range(u, ax=ax)
fig, ax = cams.plots.weight_range(t, ax=ax)
fig, ax = cams.plots.weight_range(w, ax=ax)
plt.show()
